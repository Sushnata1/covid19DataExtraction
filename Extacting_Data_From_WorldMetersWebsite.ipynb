# %% [markdown]
# # **Collecting and Parsing a Webpage**

# %%
# importing the libraries
from bs4 import BeautifulSoup
import requests

url="https://www.worldometers.info/coronavirus/"

# Make a GET request to fetch the raw HTML content
html_content = requests.get(url).text

# Parse the html content
soup = BeautifulSoup(html_content, "lxml")
#print(soup.prettify()) # print the parsed data of html

# %%
main_table = soup.find("table", attrs={"id": "main_table_countries_today"})
for th in main_table.find_all("th"):
  print(th.text.replace('\n', ' ').strip())
# Out:
# Country,Other
# TotalCases
# NewCases
# TotalDeaths
# NewDeaths
# TotalRecovered
# ActiveCases
# Serious,Critical
# Tot Cases/1M pop
# Deaths/1M pop
# TotalTests
# Tests/ 1M pop

# %%
#Fetching the data
data = {}
table = main_table
t_headers = []
for th in table.find_all("th"):
  # remove any newlines and extra spaces from left and right
  t_headers.append(th.text.replace('\n', ' ').strip())
#print(t_headers)
table_data = []
for tr in table.tbody.find_all("tr"): 
  t_row={}# find all tr's from table's tbody
  for td, th in zip(tr.find_all("td"), t_headers): 
    t_row[th] = td.text.replace('\n', '').strip()
  table_data.append(t_row)
print(table_data)
# Out:
# [{'Country,Other': 'World', 'TotalCases': '1,139,173', 'NewCases': '+22,530', 'TotalDeaths': '61,149', 'NewDeaths': '+1,991', 'TotalRecovered': '236,214', 'ActiveCases': '841,810', 'Serious,Critical': '39,667', 'Tot\xa0Cases/1M pop': '146', 'Deaths/1M pop': '7.8', 'TotalTests': '', 'Tests/ 1M pop': ''}, {'Country,Other': 'USA', 'TotalCases': '277,613', 'NewCases': '+452', 'TotalDeaths': '7,406', 'NewDeaths': '+14', 'TotalRecovered': '12,294', 'ActiveCases': '257,913', 'Serious,Critical': '5,787', 'Tot\xa0Cases/1M pop': '839', 'Deaths/1M pop': '22', 'TotalTests': '1,356,085', 'Tests/ 1M pop': '4,097'}, {'Country,Other': 'Spain', 'TotalCases': '124,736', 'NewCases': '+5,537', 'TotalDeaths': '11,744', 'NewDeaths': '+546', 'TotalRecovered': '34,219', 'ActiveCases': '78,773', 'Serious,Critical': '6,416', 'Tot\xa0Cases/1M pop': '2,668', 'Deaths/1M pop': '251', 'TotalTests': '355,000', 'Tests/ 1M pop': '7,593'}, {'Country,Other': 'Italy', 'TotalCases': '119,827', 'NewCases': '', 'TotalDeaths': '14,681', 'NewDeaths': '', 'TotalRecovered': '19,758', 'ActiveCases': '85,388', 'Serious,Critical': '4,068', 'Tot\xa0Cases/1M pop': '1,982', 'Deaths/1M pop': '243', 'TotalTests': '619,849', 'Tests/ 1M pop': '10,252'}, {'Country,Other': 'Germany', 'TotalCases': '92,050', 'NewCases': '+891', 'TotalDeaths': '1,295', 'NewDeaths': '+20', 'TotalRecovered': '24,575', 'ActiveCases': '66,180', 'Serious,Critical': '3,936', 'Tot\xa0Cases/1M pop': '1,099', 'Deaths/1M pop': '15', 'TotalTests': '918,460', 'Tests/ 1M pop': '10,962'}, {'Country,Other': 'France', 'TotalCases': '82,165', 'NewCases': '', 'TotalDeaths': '6,507', 'NewDeaths': '', 'TotalRecovered': '14,008', 'ActiveCases': '61,650', 'Serious,Critical': '6,662', 'Tot\xa0Cases/1M pop': '1,259', 'Deaths/1M pop': '100', 'TotalTests': '224,254', 'Tests/ 1M pop': '3,436'}, {'Country,Other': 'Iran', 'TotalCases': '55,743', 'NewCases': '+2,560', 'TotalDeaths': '3,452', 'NewDeaths': '+158', 'TotalRecovered': '19,736', 'ActiveCases': '32,555', 'Serious,Critical': '4,103', 'Tot\xa0Cases/1M pop': '664', 'Deaths/1M pop': '41', 'TotalTests': '80,000', 'Tests/ 1M pop': '952'}, {'Country,Other': 'UK', 'TotalCases': '41,903', 'NewCases': '+3,735', 'TotalDeaths': '4,313', 'NewDeaths': '+708', 'TotalRecovered': '135', 'ActiveCases': '37,455', 'Serious,Critical': '163', 'Tot\xa0Cases/1M pop': '617', 'Deaths/1M pop': '64', 'TotalTests': '183,190', 'Tests/ 1M pop': '2,698'}, {'Country,Other': 'Turkey', 'TotalCases': '20,921', 'NewCases': '', 'TotalDeaths': '425', 'NewDeaths': '', 'TotalRecovered': '484', 'ActiveCases': '20,012', 'Serious,Critical': '1,251', 'Tot\xa0Cases/1M pop': '248', 'Deaths/1M pop': '5', 'TotalTests': '141,716', 'Tests/ 1M pop': '1,680'}, {'Country,Other': 'Switzerland', 'TotalCases': '20,278', 'NewCases': '+672', 'TotalDeaths': '620', 'NewDeaths': '+29', 'TotalRecovered': '4,846', 'ActiveCases': '14,812', 'Serious,Critical': '391', 'Tot\xa0Cases/1M pop': '2,343', 'Deaths/1M pop': '72', 'TotalTests': '153,440', 'Tests/ 1M pop': '17,729'}, {'Country,Other': 'Belgium', 'TotalCases': '18,431', 'NewCases': '+1,661', 'TotalDeaths': '1,283', 'NewDeaths': '+140', 'TotalRecovered': '3,247', 'ActiveCases': '13,901', 'Serious,Critical': '1,245', 'Tot\xa0Cases/1M pop': '1,590', 'Deaths/1M pop': '111', 'TotalTests': '62,867', 'Tests/ 1M pop': '5,424'}, {'Country,Other': 'Netherlands', 'TotalCases': '16,627', 'NewCases': '+904', 'TotalDeaths': '1,651', 'NewDeaths': '+164', 'TotalRecovered': '250', 'ActiveCases': '14,726', 'Serious,Critical': '1,324', 'Tot\xa0Cases/1M pop': '970', 'Deaths/1M pop': '96', 'TotalTests': '75,415', 'Tests/ 1M pop': '4,401'}, {'Country,Other': 'Canada', 'TotalCases': '12,549', 'NewCases': '+174', 'TotalDeaths': '208', 'NewDeaths': '', 'TotalRecovered': '2,322', 'ActiveCases': '10,019', 'Serious,Critical': '120', 'Tot\xa0Cases/1M pop': '332', 'Deaths/1M pop': '6', 'TotalTests': '302,745', 'Tests/ 1M pop': '8,021'}, {'Country,Other': 'Austria', 'TotalCases': '11,781', 'NewCases': '+257',  ...

# %% [markdown]
# **#Writing To CSV**

# %%
import csv

with open('outputdata.csv', 'w') as outfile:
    mywriter = csv.DictWriter(outfile, fieldnames=t_headers)
    mywriter.writeheader()
    for d in table_data:
        mywriter.writerow(d)

# %%
import pandas as pd
df = pd.read_csv('outputdata.csv')
df.head(5)
# Out:
#   Country,Other TotalCases NewCases  ... Deaths/1M pop TotalTests Tests/ 1M pop
# 0         World  1,139,173  +22,530  ...           7.8        NaN           NaN
# 1           USA    277,613     +452  ...          22.0  1,356,085         4,097
# 2         Spain    124,736   +5,537  ...         251.0    355,000         7,593
# 3         Italy    119,827      NaN  ...         243.0    619,849        10,252
# 4       Germany     92,050     +891  ...          15.0    918,460        10,962
#
# [5 rows x 12 columns]
